# %%
print("Week 0 environment check")
# Out:
# Week 0 environment check

# %%
import sys
print("Python executable:", sys.executable)
print("Python version:", sys.version)
# Out:
# Python executable: /Users/saanvikakde/FURI_SP26/venv/bin/python
# Python version: 3.14.2 (main, Dec  5 2025, 16:49:16) [Clang 17.0.0 (clang-1700.4.4.1)]

# %%
import sys, subprocess

print("Running pip --version ...")
subprocess.run([sys.executable, "-m", "pip", "--version"], check=False)
# Out:
# Running pip --version ...
# pip 25.3 from /Users/saanvikakde/FURI_SP26/venv/lib/python3.14/site-packages/pip (python 3.14)
# CompletedProcess(args=['/Users/saanvikakde/FURI_SP26/venv/bin/python', '-m', 'pip', '--version'], returncode=0)

# %%
import sys, subprocess

pkgs = [
    "numpy", "pandas", "matplotlib",
    "geopandas", "shapely", "pyproj", "fiona",
    "rasterio",
    "transformers", "torch",
    "nltk", "spacy",
    "earthengine-api"
]

subprocess.run([sys.executable, "-m", "pip", "install", "-q", "--upgrade", "pip"], check=False)
subprocess.run([sys.executable, "-m", "pip", "install", "-q"] + pkgs, check=False)

print("Installed")
# Out:
# Installed

# %%
import numpy as np
import pandas as pd
import matplotlib
import geopandas as gpd
import shapely
import pyproj
import fiona
import rasterio

from transformers import pipeline

print("All imports successful")
print("numpy:", np.__version__)
print("pandas:", pd.__version__)
print("geopandas:", gpd.__version__)
print("rasterio:", rasterio.__version__)
print("transformers imported")
# Out:
# All imports successful
# numpy: 2.4.1
# pandas: 3.0.0
# geopandas: 1.1.2
# rasterio: 1.5.0
# transformers imported

# %%
from shapely.geometry import Point
gdf = gpd.GeoDataFrame(
    {"name": ["test_point"], "geometry": [Point(-111.93, 33.42)]},  # near Tempe/Phoenix
    crs="EPSG:4326"
)
gdf
# Out:
#          name               geometry
# 0  test_point  POINT (-111.93 33.42)

# %%
ax = gdf.plot()
ax.set_title("GeoPandas plot works")
# Out:
# Text(0.5, 1.0, 'GeoPandas plot works')

# %%
sentiment = pipeline("sentiment-analysis")
sentiment("I feel calm walking through the park today.")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use mps:0
# [{'label': 'POSITIVE', 'score': 0.997565507888794}]

# %%
import nltk
nltk.download("punkt")
print("NLTK punkt downloaded")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/saanvikakde/nltk_data...
# NLTK punkt downloaded
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
import ee
print("Earth Engine imported")
# Out:
# Earth Engine imported
